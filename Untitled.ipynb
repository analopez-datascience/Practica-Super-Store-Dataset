# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('SuperStoreOrders.csv')

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  6/1/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  5/1/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  5/1/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %% [raw]
# df.info()

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isna().values.any()
# Out:
# False

# %%
max_ruta = df[df.shipping_cost == df.shipping_cost.max()]
min_ruta = df[df.shipping_cost == df.shipping_cost.min()]

max_ruta[['country','market','region','shipping_cost']].drop_duplicates()
# Out:
#              country market region  shipping_cost
# 13891  United States     US   East         933.57

# %%
min_ruta[['country','market','region','shipping_cost']].drop_duplicates()
# Out:
#          country market   region  shipping_cost
# 9827      Brazil  LATAM    South            0.0
# 11846  Nicaragua  LATAM  Central            0.0

# %% [markdown]
# ### venta por años

# %%
# Preparar los datos
plotdata = df.year.value_counts()

#Gráfico de barras + Títulos
plotdata.plot(kind='bar', title = 'Registros de venta por año')
plt.ylabel("Registres")
# Out:
# Text(0, 0.5, 'Registres')

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  6/1/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  5/1/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  5/1/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
df.profit.mean()
# Out:
# 28.641739545330367

# %%
df.describe()
# Out:
#            quantity      discount        profit  shipping_cost          year
# count  51290.000000  51290.000000  51290.000000   51290.000000  51290.000000
# mean       3.476545      0.142908     28.641740      26.375915   2012.777208
# std        2.278766      0.212280    174.424113      57.296804      1.098931
# min        1.000000      0.000000  -6599.978000       0.000000   2011.000000
# 25%        2.000000      0.000000      0.000000       2.610000   2012.000000
# 50%        3.000000      0.000000      9.240000       7.790000   2013.000000
# 75%        5.000000      0.200000     36.810000      24.450000   2014.000000
# max       14.000000      0.850000   8399.976000     933.570000   2014.000000

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
data1 = df.groupby('segment').agg({'order_id':'count',
                                   'profit':'mean',
                                 'discount':'mean'}).round(2)
data1
# Out:
#              order_id  profit  discount
# segment
# Consumer        26518   28.25      0.14
# Corporate       15429   28.70      0.14
# Home Office      9343   29.65      0.14

# %%
data2 = df.groupby('category').agg({'order_id':'count',
                                   'profit':'mean',
                                 'discount':'mean'}).round(2)
data2
# Out:
#                  order_id  profit  discount
# category
# Furniture            9876   29.04      0.17
# Office Supplies     31273   16.58      0.14
# Technology          10141   65.45      0.14

# %%
data3 = data2 = df.groupby('sub_category').agg({'order_id':'count', 'sales':'mean',
                                   'profit':'mean',
                                 'discount':'mean'}).round(2)
data2
# Out:
#               order_id   sales  profit  discount
# sub_category
# Accessories       3075  185.44   42.15      0.12
# Appliances        1755  215.51   80.73      0.14
# Art               4883   75.99   11.87      0.12
# Binders           6152   56.28   11.78      0.18
# Bookcases         2411  336.86   67.16      0.15
# Chairs            3434  270.40   41.34      0.16
# Copiers           2223  352.42  116.31      0.12
# Envelopes         2435   70.20   12.16      0.13
# Fasteners         2420   34.40    4.76      0.14
# Furnishings       3170  119.07   14.82      0.15
# Labels            2606   28.18    5.76      0.12
# Machines          1486  279.51   39.61      0.17
# Paper             3538   69.05   16.73      0.11
# Phones            3357  259.56   64.56      0.15
# Storage           5059  180.61   21.44      0.14
# Supplies          2425   86.64    9.31      0.13
# Tables             861  337.00  -74.43      0.29

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  object
#  2   ship_date       51290 non-null  object
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  object
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
# ...

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  6/1/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  5/1/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  5/1/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
df['sales'] = df['sales'].str.replace(",",".")
df['sales'] = df['sales'].astype(float)

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  6/1/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  5/1/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  5/1/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name  sales  quantity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  object
#  2   ship_date       51290 non-null  object
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  float64
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
# ...

# %%
data4 = df.groupby('market').agg({'order_id':'count',
                                  'sales':'sum',
                                  'quantity':'mean',
                                    'profit':'mean',
                                 'discount':'mean',
                                 'shipping_cost':'mean'}).round(2)
data4
# Out:
#         order_id       sales  quantity  profit  discount  shipping_cost
# market
# APAC       11002  2002331.09      3.75   39.77      0.15          35.19
# Africa      4587   538360.66      2.30   19.37      0.16          19.22
# Canada       384    50330.62      2.17   46.40      0.00          19.29
# EMEA        5029   575792.62      2.29    8.73      0.20          17.57
# EU         10000  1804234.04      3.78   37.28      0.10          30.94
# LATAM      10294  1563727.56      3.74   21.53      0.14          22.75
# US          9994  1305159.19      3.79   28.66      0.16          23.83

# %% [markdown]
# ### venta por paises

# %%
plotdata
# Out:
# 2014    17531
# 2013    13799
# 2012    10962
# 2011     8998
# Name: year, dtype: int64

# %%
import squarify
plotdata = df.market.value_counts()

plt.figure(figsize=(12, 6))
plt.axis('off')
axis = squarify.plot(sizes=plotdata.values, label=plotdata.index, alpha=.8, pad=1, text_kwargs={'fontsize': 14})

axis.set_title("Barris", fontsize=20)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 import squarify
#       2 plotdata = df.market.value_counts()
#       4 plt.figure(figsize=(12, 6))
#
# ModuleNotFoundError: No module named 'squarify'

# %%
# Preparar los datos
plotdata = df.market.value_counts()

#Gráfico de barras + Títulos
plotdata.plot(kind='bar', title = 'Registres per a cada regio')
plt.xlabel("Nom Districte")
plt.ylabel("Registres")
# Out:
# Text(0, 0.5, 'Registres')

# %%
data1 = df[df['market'] == 'US']

# %%
df.category.value_counts()
# Out:
# Office Supplies    31273
# Technology         10141
# Furniture           9876
# Name: category, dtype: int64

# %%
df.sub_category.value_counts()
# Out:
# Binders        6152
# Storage        5059
# Art            4883
# Paper          3538
# Chairs         3434
# Phones         3357
# Furnishings    3170
# Accessories    3075
# Labels         2606
# Envelopes      2435
# Supplies       2425
# Fasteners      2420
# Bookcases      2411
# Copiers        2223
# Appliances     1755
# Machines       1486
# Tables          861
# Name: sub_category, dtype: int64

# %%
df.groupby('market').profit.value_counts()
# Out:
# market  profit
# APAC    0.0000       109
#         4.3200        25
#         12.6000       18
#         9.0000        17
#         5.4000        14
#                     ...
# US      4630.4755      1
#         4946.3700      1
#         5039.9856      1
#         6719.9808      1
#         8399.9760      1
# Name: profit, Length: 31033, dtype: int64

# %%
df.customer_name.value_counts()
# Out:
# Muhammed Yedwab        108
# Steven Ward            106
# Patrick O'Brill        102
# Bill Eplett            102
# Gary Hwang             102
#                       ...
# Catherine Glotzbach     35
# David Bremer            34
# Nicole Brennan          31
# Darren Budd             31
# Michael Oakman          29
# Name: customer_name, Length: 795, dtype: int64

# %%
df = pd.read_csv('https://docs.google.com/spreadsheets/d/1hR1ZzEYLGnyWF-DAUz8duqk5w-QHoCxB2ygC0U4fkz4/edit#gid=0.xlsx', sep='\t', encoding='utf-8')

# %%
df

# %%
# !pip install fastapi

# %%
# !pip install uvicorn

# %%
from fastapi import FastAPI
app = FastAPI()

@app.get("/get-iris")
def get_iris():

    import pandas as pd
    url ='https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv'
    iris = pd.read_csv(url)

    return iris
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 from fastapi import FastAPI
#       2 app = FastAPI()
#       4 @app.get("/get-iris")
#       5 def get_iris():
#
# ModuleNotFoundError: No module named 'fastapi'

# %%
get_iris()

# %%
resp.text

# %%
uvicorn main:app --reload
